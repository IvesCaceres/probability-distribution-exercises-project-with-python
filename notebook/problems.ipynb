# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
print(dbinom(2, size = 10, prob = 0.2)) #Probability that a binomial (10,0.2) takes the value 2,
print(pbinom(2, size = 10, prob = 0.2)) #Probability that a binomial (10,0.2) will take a value less than 2
print(qbinom(0.9, size = 10, prob = 0.2)) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
print(rbinom(2000, size = 10, prob = 0.2)) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# 0.30198988800000004
# 0.6777995263999999
# 4.0
# [3 1 1 ... 2 1 0]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
#Code here
from scipy.stats import norm 
def dnor(x, mean = 0 ,stdv= 1):
    """
    Probability density function. pdf
    """
    result=norm.pdf(x,loc = mean, scale = stdv)
    return result

def cnor(x, mean = 0 ,stdv= 1):
    """
    Probability cumulative function. cdf
    """
    result=norm.cdf(x,loc = mean, scale = stdv)
    return result


def qnor(x, mean = 0 ,stdv= 1):
    """
    Probability quantile function. ppf
    """
    result=norm.ppf(x,loc = mean, scale = stdv)
    return result

def rnor(x, mean = 0 ,stdv= 1):
    """
    Probability random variables function. ppf
    """
    result = norm.rvs(loc = mean, scale = stdv, size = x)
    return result

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1,2, figsize=(10,5))

x = np.arange(-5,5,0.1)
axs[0].plot(x,dnor(x,mean=0,stdv=1))
axs[0].set_title('Probability density function')
axs[1].plot(x,cnor(x,mean=0,stdv=1))
axs[1].set_title('Probability density function')


plt.show()
